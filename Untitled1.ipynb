# %%
# Cars from trade me

# %% [markdown]
# #### Pandas has three main base classes
#
# - pd   -->   pandas     ie import pandas as pd
# - df   -->   dataframe  ie pd.read_csv('./random.csv')
# - s    -->   series     ie df['col_name']
#
#
# ### Read Data
#
# | Function        | Description                 |      Info                                            |
# |:----------------|:----------------------------|:-----------------------------------------------------|
# | pd.read_excel() | Read spreadsheet            | .xls or .xlsx                                        |
# | pd.read_json()  | Read JSON document          | .json                                                |
# | pd.read_sql()   | Read directly from DB query | Needs 3rd party library to support (e.g. sqlalchemy) |
# | df.to_csv()     | Write to CSV file           | .csv, .tsv or .txt                                   |
# | df.to_excel()   | Write to Excel file         | .xls or .xlsx                                        |
# | df.to_json()    | Write to JSON document      | .json                                                |
# | df.to_sql()     | Write to DB table           | Needs 3rd party library to support (e.g. sqlalchemy) |
# | pd.read_csv()   | Read CSV file               | .csv, .tsv or .txt                                   |
#
#
#
# ### Descirbe data
# | Function        | Description          | Info                                                           |
# |:-----------------|:-----------------------------------------|:---------------------------------------------------------------------------------------|
# | df.tail()        | Preview the last n (default=5)           | Can define "n" by df.tail(n)                                                           |
# | df.sort_values() | Sort the data frame on a specific column | Can sort with multiple columns, either ascending or descending                         |
# | df.columns       | Display all column names                 | Can also set column names by assign a list of column names                             |
# | df.dtypes        | Display data types of the columns        | Return a list of types                                                                 |
# | df.shape         | Display the shape of the data frame      | Return a tuple: (row_count, col_count)                                                 |
# | df.describe()    | Show basic stats of each column          | Will show different stats for different types of column (numerical, datetime and etc.) |
# | s.value_counts() | Count occurrences of each value          | Use df['...'] to get a column of data frame as series                                  |
# | df.head()        | Preview the first n (default=5)          | Can define "n" by df.head(n)                                                           |
#
#
# ### Clean data
#
# | Function        | Description          | Info                                                           |
# |:---------------------|:-----------------------------------------|:-------------------------------------------------------------------|
# | df.dropna()          | Delete missing values                    | Can be applied on a series or a data frame                         |
# | df.fillna()          | Fill missing values with a certain value | Can be applied on a series or a data frame                         |
# | df.drop_duplicates() | Delete all duplicated values             | Can be applied on a series or a data frame                         |
# | df.drop()            | Delete columns or rows                   | Need to specify axis                                               |
# | df.rename()          | Rename columns or rows                   | Need to specify axis                                               |
# | df.reset_index()     | Convert index column to a data column    | A new index will be automatically added using incremental integers |
# | s.isna()             | Whether there are null values existing   | Boolean                                                            |
#
#
# ### Transform data
# | Function        | Description          | Info                                                           |
# |:-----------------|:-----------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------|
# | s.astype()       | Convert column data type                                                     | Need to be careful to NaN values when convert between float/double and integer                  |
# | s.apply()        | Invoke function on values of Series                                          | Very flexible function that you must practice a lot                                             |
# | df.apply()       | Apply a function along an axis of the DataFrame                              | When you need to apply a function on multiple columns                                           |
# | df.explode()     | Transform each element of a list-like to a row, replicating the index values | When you used df.apply to return multiple column in a list, then translate them back to columns |
# | pd.to_datetime() | Convert string column to datetime                                            | Support customised format                                                                       |
#
#
#
# ### Aggregate data
#
# | Function        | Description          | Info                                                           |
# |:-------------------|:-------------------------------------------------------------|:--------------------------------------------------------------------------------------|
# | pd.merge()         | Joining two data frames                                      | Just like joining tables in DB, need to be careful joining methods (left/right/inner) |
# | df.groupby()       | Grouping column(s) and then apply more aggregating functions | Very commonly used with agg() function                                                |
# | df.groupby().agg() | Aggregating records for each group                           | Need to be used along with groupby() function                                         |
# | pd.pivot_table()   | Convert data frame to pivot table                            | May have multi-level indices and columns                                              |
# | pd.concat()        | Concatenate two dataframe                                    | Can be horizontal or vertical                                                         |

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# read data

df = pd.read_csv('./2004.csv')

# %%
df.head()
# Out:
#   ALTERNATIVE_MOTIVE_POWER BASIC_COLOUR         BODY_TYPE  CC_RATING CHASSIS7  \
# 0                      NaN        WHITE     STATION WAGON       2480  TZ50-00
# 1                      NaN       SILVER         HATCHBACK       1290  NCP20-0
# 2                      NaN       SILVER     STATION WAGON       1790  ZNE10-0
# 3                      NaN        WHITE     STATION WAGON       2360  ACM21-5
# 4                      NaN       SILVER  DOMESTIC TRAILER          0   204173
#
#   CLASS ENGINE_NUMBER  FIRST_NZ_REGISTRATION_YEAR  \
# 0    MA  QR25-2416441                      2017.0
# 1    MA    2NZ-322058                      2015.0
# 2    MA    1ZZ-101097                      2017.0
# 3    MA   2AZ-4802234                      2015.0
# 4    TB           NaN                      2004.0
#
#    FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS  ...  ROAD_TRANSPORT_CODE  \
# 0                          2.0                1925  ...                  NaN
# ...

# %%
df.describe()
# Out:
#            CC_RATING  FIRST_NZ_REGISTRATION_YEAR  FIRST_NZ_REGISTRATION_MONTH  \
# count  246700.000000               246699.000000                246699.000000
# mean     2143.650730                 2009.463455                     6.643805
# std      1611.448896                    5.089359                     3.465098
# min         0.000000                 2003.000000                     1.000000
# 25%      1490.000000                 2004.000000                     4.000000
# 50%      1990.000000                 2010.000000                     7.000000
# 75%      2461.000000                 2014.000000                    10.000000
# max     90000.000000                 2020.000000                    12.000000
#
#        GROSS_VEHICLE_MASS         HEIGHT  NUMBER_OF_AXLES  NUMBER_OF_SEATS  \
# count       246700.000000  246700.000000    246700.000000    246700.000000
# mean          1998.367941      88.065586         1.491982         4.666469
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246700 entries, 0 to 246699
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ALTERNATIVE_MOTIVE_POWER     6287 non-null    object
#  1   BASIC_COLOUR                 246700 non-null  object
#  2   BODY_TYPE                    246700 non-null  object
#  3   CC_RATING                    246700 non-null  int64
#  4   CHASSIS7                     151401 non-null  object
#  5   CLASS                        227812 non-null  object
#  6   ENGINE_NUMBER                224297 non-null  object
#  7   FIRST_NZ_REGISTRATION_YEAR   246699 non-null  float64
#  8   FIRST_NZ_REGISTRATION_MONTH  246699 non-null  float64
#  9   GROSS_VEHICLE_MASS           246700 non-null  int64
#  10  HEIGHT                       246700 non-null  int64
#  11  IMPORT_STATUS                246700 non-null  object
# ...

# %%
# Checking null values
df.isnull().any()
# Out:
# ALTERNATIVE_MOTIVE_POWER        True
# BASIC_COLOUR                   False
# BODY_TYPE                      False
# CC_RATING                      False
# CHASSIS7                        True
# CLASS                           True
# ENGINE_NUMBER                   True
# FIRST_NZ_REGISTRATION_YEAR      True
# FIRST_NZ_REGISTRATION_MONTH     True
# GROSS_VEHICLE_MASS             False
# HEIGHT                         False
# IMPORT_STATUS                  False
# INDUSTRY_CLASS                 False
# INDUSTRY_MODEL_CODE             True
# MAKE                           False
# MODEL                           True
# MOTIVE_POWER                    True
# MVMA_MODEL_CODE                 True
# NUMBER_OF_AXLES                False
# NUMBER_OF_SEATS                False
# NZ_ASSEMBLED                   False
# ORIGINAL_COUNTRY               False
# POWER_RATING                   False
# PREVIOUS_COUNTRY               False
# ROAD_TRANSPORT_CODE             True
# ...

# %%
# Counting null values
df.isnull().sum()
# Out:
# ALTERNATIVE_MOTIVE_POWER       240413
# BASIC_COLOUR                        0
# BODY_TYPE                           0
# CC_RATING                           0
# CHASSIS7                        95299
# CLASS                           18888
# ENGINE_NUMBER                   22403
# FIRST_NZ_REGISTRATION_YEAR          1
# FIRST_NZ_REGISTRATION_MONTH         1
# GROSS_VEHICLE_MASS                  0
# HEIGHT                              0
# IMPORT_STATUS                       0
# INDUSTRY_CLASS                      0
# INDUSTRY_MODEL_CODE            108967
# MAKE                                0
# MODEL                               1
# MOTIVE_POWER                    21447
# MVMA_MODEL_CODE                167185
# NUMBER_OF_AXLES                     0
# NUMBER_OF_SEATS                     0
# NZ_ASSEMBLED                        0
# ORIGINAL_COUNTRY                    0
# POWER_RATING                        0
# PREVIOUS_COUNTRY                    0
# ROAD_TRANSPORT_CODE            243521
# ...

# %%
df.nunique()
# Out:
# ALTERNATIVE_MOTIVE_POWER            8
# BASIC_COLOUR                       14
# BODY_TYPE                          25
# CC_RATING                        1361
# CHASSIS7                        11200
# CLASS                              19
# ENGINE_NUMBER                  199803
# FIRST_NZ_REGISTRATION_YEAR         18
# FIRST_NZ_REGISTRATION_MONTH        12
# GROSS_VEHICLE_MASS               1753
# HEIGHT                            394
# IMPORT_STATUS                       4
# INDUSTRY_CLASS                     14
# INDUSTRY_MODEL_CODE              4615
# MAKE                              290
# MODEL                            7694
# MOTIVE_POWER                        8
# MVMA_MODEL_CODE                  2371
# NUMBER_OF_AXLES                     8
# NUMBER_OF_SEATS                    57
# NZ_ASSEMBLED                        3
# ORIGINAL_COUNTRY                   38
# POWER_RATING                      235
# PREVIOUS_COUNTRY                   33
# ROAD_TRANSPORT_CODE                20
# ...

# %%
# Plotting features to get distribution idea of dataset features
df.hist(bins=50, figsize=(30,30))
plt.show()

# %%
# cc = pd.DataFrame({'height': height, 'weight': weight})

type(df['CC_RATING'])
dir(df['CC_RATING'])
# .plot(kind="scatter",x="longitude", y="latitude",alpha=0.1)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
frame = df['CC_RATING'].to_frame()
frame
# Out:
#         CC_RATING
# 0            2480
# 1            1290
# 2            1790
# 3            2360
# 4               0
# ...           ...
# 246695       2499
# 246696       2990
# 246697       2953
# 246698       1490
# 246699       2480
#
# [246700 rows x 1 columns]

# %%
# frame.plot(kind="scatter",x="longitude", y="latitude",alpha=0.1)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246700 entries, 0 to 246699
# Data columns (total 1 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   CC_RATING  246700 non-null  int64
# dtypes: int64(1)
# memory usage: 1.9 MB

# %%
# plt.scatter(frame, df.BODY_TYPE)

# plt.scatter(frame, df.BODY_TYPE)

# %%
# df2 = pd.DataFrame(df, columns = ['CC_RATING', 'BODY_TYPE'])

# %%
# df2.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-318d12b1eabf> in <module>
# ----> 1 df2.plot()
#
# AttributeError: 'NoneType' object has no attribute 'plot'

# %%
# df2.hist()

# %%
# number of unique items

df['BODY_TYPE'].nunique()
# Out:
# 25

# %%
# unique items vs feq



df.BODY_TYPE.value_counts()
# Out:
# STATION WAGON                78117
# HATCHBACK                    65049
# SALOON                       44976
# UTILITY                      12380
# DOMESTIC TRAILER             10885
# LIGHT VAN                     7082
# MOTORCYCLE                    5494
# BOAT TRAILER                  5053
# OTHER TRUCK                   3078
# OTHER COMMERCIAL TRAILER      2510
# CARAVAN                       2351
# SPORTS CAR                    1884
# CONVERTIBLE                   1357
# SELF PROPELLED CARAVAN        1248
# TRACTOR                       1221
# MOBILE MACHINE                 753
# MINIBUS                        633
# FLAT-DECK TRAILER              606
# HEAVY VAN                      580
# FLAT-DECK TRUCK                498
# ARTICULATED TRUCK              459
# SERVICE COACH                  279
# CAB AND CHASSIS ONLY           103
# AG MACHINE - OTHER              62
# NON HIGHWAY TRAILER-OTHER       42
# Name: BODY_TYPE, dtype: int64

# %%
df.BODY_TYPE.hist()

plt.xticks(rotation='vertical')

plt.show()

# %%
# These are the outliers in CC_RATING. Some are trucks some are mislabeled.
# ie This wagon is probably not 30,000cc  ->> STATION WAGON - 29901 - OUTBACK

# df.CC_RATING.quantile(.99) 

## New DF with only large CC
# filtered = df[df.CC_RATING > df.CC_RATING.quantile(.99)]

## New DF without large CC
# filtered = df[df.CC_RATING > df.CC_RATING.quantile(.99)]

## New DF without all 0cc (DOMESTIC TRAILER)
# filtered = df[df.CC_RATING < 0.1]

## New DF removing all 0cc (DOMESTIC TRAILER)
# filtered = df[df.CC_RATING > 0.1]

# filtered.head()

# %%
df.CC_RATING.quantile(.3)
# Out:
# 1490.0

# %%
df.VEHICLE_TYPE.value_counts()
# Out:
# PASSENGER CAR/VAN                     193463
# GOODS VAN/TRUCK/UTILITY                22093
# TRAILER/CARAVAN                        21405
# MOTORCYCLE                              4701
# MOTOR CARAVAN                           1248
# TRACTOR                                 1218
# BUS                                      912
# MOBILE MACHINE                           713
# MOPED                                    598
# ATV                                      185
# AGRICULTURAL MACHINE                      62
# SPECIAL PURPOSE VEHICLE                   56
# TRAILER NOT DESIGNED FOR H/WAY USE        42
# HIGH SPEED AGRICULTURAL VEHICLE            4
# Name: VEHICLE_TYPE, dtype: int64

# %%
df.VEHICLE_TYPE.hist()
plt.xticks(rotation='vertical')
plt.show()

# %%
df.dtypes
# Out:
# ALTERNATIVE_MOTIVE_POWER        object
# BASIC_COLOUR                    object
# BODY_TYPE                       object
# CC_RATING                        int64
# CHASSIS7                        object
# CLASS                           object
# ENGINE_NUMBER                   object
# FIRST_NZ_REGISTRATION_YEAR     float64
# FIRST_NZ_REGISTRATION_MONTH    float64
# GROSS_VEHICLE_MASS               int64
# HEIGHT                           int64
# IMPORT_STATUS                   object
# INDUSTRY_CLASS                  object
# INDUSTRY_MODEL_CODE             object
# MAKE                            object
# MODEL                           object
# MOTIVE_POWER                    object
# MVMA_MODEL_CODE                 object
# NUMBER_OF_AXLES                  int64
# NUMBER_OF_SEATS                  int64
# NZ_ASSEMBLED                    object
# ORIGINAL_COUNTRY                object
# POWER_RATING                     int64
# PREVIOUS_COUNTRY                object
# ...

# %%
df.shape
# Out:
# (246700, 34)

# %%
df.VEHICLE_YEAR.shape
# Out:
# (246700,)

# %%
7/1
# Out:
# 7.0

# %%
1/7
# Out:
# 0.14285714285714285
